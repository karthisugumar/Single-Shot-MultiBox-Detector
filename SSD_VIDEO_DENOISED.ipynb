# %%
# %matplotlib inline
import os
import os.path as osp
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import torchvision as tv

from PIL import Image
import matplotlib.pyplot as plt
import nntools as nt
import math

import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import torch.backends.cudnn as cudnn

import cv2
from ssd import build_ssd
import random

from data import VOCDetection, VOC_ROOT, VOCAnnotationTransform
from data import VOC_CLASSES as labels

# %%
if sys.version_info[0] == 2:
    import xml.etree.cElementTree as ET
else:
    import xml.etree.ElementTree as ET

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cpu

# %%
VOC_ROOT= 'D:\\Spring 19\\ECE 285\VOC\\VOCdevkit\\'

# %%
def myimshow(image, ax=plt):
    image = image.to('cpu').numpy()
    image = np.moveaxis(image, [0, 1, 2], [2, 0, 1])
    image = (image + 1) / 2
    image[image < 0] = 0
    image[image > 1] = 1
    h = ax.imshow(image)
    ax.axis('off')
    return h

# %%
net = build_ssd('test', 300, 21)    # initialize SSD
net.load_weights('ssd300_mAP_77.43_v2.pth')
# Out:
# C:\Users\karth\ECE 285\Project_SSD\ssd.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   self.priors = Variable(self.priorbox.forward(), volatile=True)
# Loading weights into state dict...
# Finished!

# %%
class NNRegressor(nt.NeuralNetwork):
    
    def __init__(self):
        super(NNRegressor, self).__init__()
        self.mse = nn.MSELoss()
        
    def criterion(self, y, d):
        return self.mse(y, d)

# %%
class DUDnCNN(NNRegressor):
    
    def __init__(self, D, C=64):
        super(DUDnCNN, self).__init__()
        self.D = D
        self.conv = nn.ModuleList()
        
        self.conv.append(nn.Conv2d(3, C, 3, padding=1)) # Padding = (3-1)/2 ==> 1
        
        for k in range(D):
            if (k == D/2):
                l = 1
            elif(k > D/2):
                l += 2
            else:
                l = 0
            
            dil = int(1 + 2**(k-l) -1)
            self.conv.append(nn.Conv2d(C, C, 3, padding=dil, dilation=dil))
        
        self.conv.append(nn.Conv2d(C, 3, 3, padding=1))
        
        self.bn = nn.ModuleList()
        for k in range(D):
            self.bn.append(nn.BatchNorm2d(C, C))
    
        for k in range(len(self.conv)-1):
            self.conv[k].weight.data = nn.init.kaiming_normal_(self.conv[k].weight.data, nonlinearity='relu')
        
        for k in range(D):    
            self.bn[k].weight.data = nn.init.constant_(self.bn[k].weight.data, 1.25 * np.sqrt(C))
        
    def forward(self, x):
        D = self.D
        h = F.relu(self.conv[0](x))
        for k in range(D):
            torch.backends.cudnn.benchmark=True  # Q20 
            h = self.conv[k+1](h)
            torch.backends.cudnn.benchmark=False  # Q20
            h = F.relu(self.bn[k](h))
        
        y = self.conv[D+1](h) + x
        return y

# %%
net_DUDnCNN = torch.load('denNet.pt')

# %%
def readImage(path, noisy=False, plot=False):
    orig = cv2.imread(impath, cv2.IMREAD_COLOR)
    rgb_image = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB)
    orig_shape = orig.shape
    noisy_image = None
    
    if noisy:
        noisy_orig = orig[...,::-1]/255.0
        noise =  np.random.normal(loc=0, scale=1, size=noisy_orig.shape)
        noise2 = (noise - noise.min())/(noise.max()-noise.min())

        # noise overlaid over image
        noisy = np.clip((noisy_orig + noise*0.2),0,1)
        noisy2 = np.clip((noisy_orig + noise*0.4),0,1)
        orig = noisy2*255.0
        noisy_image = orig
        
    x = cv2.resize(orig, (300, 300)).astype(np.float32)
    x -= (104.0, 117.0, 123.0)
    x = x.astype(np.float32)
    x = x[:, :, ::-1].copy()
    x = torch.from_numpy(x).permute(2, 0, 1)

    if plot:
        plt.figure(figsize=(10,5))
        plt.subplot(121)
        plt.imshow(rgb_image)
        plt.subplot(122)
        plt.imshow((x*255).astype(np.uint8))

    return x, rgb_image, noisy_image

# %%
def getDenoised(noisy_image, net_DUDnCNN):
    denoised = noisy_image
    im = Image.fromarray(np.uint8(denoised))
    image_size = (300,300)

    # declare a tranform to convert the image to a tensor and normalize it between [-1, 1]
    transform = tv.transforms.Compose([tv.transforms.Resize(image_size),
                                tv.transforms.ToTensor(), tv.transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])]) 
    
    denoised = transform(im).unsqueeze(0)
    y = (net_DUDnCNN.forward(denoised)).detach()
    denoised = y[0].permute(1,2,0).numpy()
    denoised = 255.0*((denoised+1)/2)
    
    im2 = Image.fromarray(np.uint8(denoised))
    tran = tv.transforms.Compose([tv.transforms.Resize((rgb_image.shape[0],rgb_image.shape[1])), tv.transforms.ToTensor()])
    denoised = tran(im2)
    denoised = (tran(im2)*255.0).permute(1,2,0).numpy()

    x = cv2.resize(denoised, (300, 300)).astype(np.float32)
    x -= (104.0, 117.0, 123.0)
    x = x.astype(np.float32)
    x = x[:, :, ::-1].copy()
    x = torch.from_numpy(x).permute(2, 0, 1)
    
    return x, denoised

# %%
VIDEO_ROOT = 'D:\\Spring 19\\ECE 285\\Project_SSD\\video\\600_frames\\'

# %%
image_name = random.choice(os.listdir(VIDEO_ROOT))
impath = VIDEO_ROOT + image_name
print(impath)
# Out:
# D:\Spring 19\ECE 285\Project_SSD\video\600_frames\NYC00543.jpg

# %% [markdown]
# #### Get noisy image

# %%
x,rgb_image,noisy_image = readImage(impath, noisy=True)

# %% [markdown]
# #### Get denoised image using DUDnCNN

# %%
x, denoised_image = getDenoised(noisy_image, net_DUDnCNN)

# %%
img = x.unsqueeze(0)
y = net(img)

# %% [markdown]
# ### CV2 SAVE

# %%
top_k=10

figure = plt.figure(figsize=(10,10))

detections = y.data

# scale each detection back up to the image
scale = torch.Tensor(rgb_image.shape[1::-1]).repeat(2)

for i in range(detections.size(1)):
    j = 0
    while detections[0,i,j,0] >= 0.6:
        score = detections[0,i,j,0]
        label_name = labels[i-1]
        display_txt = '%s: %.2f'%(label_name, score)
        pt = (detections[0,i,j,1:]*scale).cpu().numpy()
        coords = (pt[0], pt[1]), pt[2]-pt[0]+1, pt[3]-pt[1]+1
        
        if j==0:
            im = cv2.rectangle(denoised_image,(pt[0],pt[1]),(pt[2], pt[3]),(0,255,0),3)
        else:
            im = cv2.rectangle(im,(pt[0],pt[1]),(pt[2], pt[3]),(0,255,0),3)
        
        im = cv2.rectangle(im,(int(pt[0]-25),int(pt[1]-20)),(int(pt[0]+100), int(pt[1]+5)),(0,255,0),-1)
        
        text_coor = int(pt[0]-21)
        if text_coor<0:
            text_coor = 2
        im = cv2.putText(im,display_txt,(text_coor,pt[1]), cv2.FONT_HERSHEY_DUPLEX, 0.6,(0,0,0),1,cv2.LINE_AA)
        j+=1
        
plt.figure(figsize=(10,10))
# plt.imshow(im)
# cv2.imwrite("sample.jpg", temp)

# %% [markdown]
# ### FRAMES

# %%
VIDEO_OUT_ROOT = 'D:\\Spring 19\\ECE 285\\Project_SSD\\video\\600_frames_out_DENOISED2\\'

# %%
figure = plt.figure(figsize=(10,10))
for filename in os.listdir(VIDEO_ROOT):
    impath = VIDEO_ROOT + str(filename)
    print("Working on " + str(filename))
    
    x,rgb_image,noisy_image = readImage(impath, noisy=True)
    x, denoised_image = getDenoised(noisy_image, net_DUDnCNN)
    
    img = x.unsqueeze(0)     # wrap tensor in Variable
    y = net(img)
    
    top_k=10

    detections = y.data
    # scale each detection back up to the image
    scale = torch.Tensor(rgb_image.shape[1::-1]).repeat(2)
    for i in range(detections.size(1)):
        j = 0
        while detections[0,i,j,0] >= 0.6:
            score = detections[0,i,j,0]
            label_name = labels[i-1]
            display_txt = '%s: %.2f'%(label_name, score)
            pt = (detections[0,i,j,1:]*scale).cpu().numpy()
            coords = (pt[0], pt[1]), pt[2]-pt[0]+1, pt[3]-pt[1]+1

            if j==0:
                im = cv2.rectangle(denoised_image,(pt[0],pt[1]),(pt[2], pt[3]),(0,255,0),3)
            else:
                im = cv2.rectangle(im,(pt[0],pt[1]),(pt[2], pt[3]),(0,255,0),3)

            im = cv2.rectangle(im,(int(pt[0]-25),int(pt[1]-20)),(int(pt[0]+100), int(pt[1]+5)),(0,255,0),-1)

            text_coor = int(pt[0]-21)
            if text_coor<0:
                text_coor = 2
            im = cv2.putText(im,display_txt,(text_coor,pt[1]), cv2.FONT_HERSHEY_DUPLEX, 0.6,(0,0,0),1,cv2.LINE_AA)
            j+=1

    cv2.imwrite((VIDEO_OUT_ROOT+str(filename)), im)
# Out:
# Working on NYC00022.jpg
# Working on NYC00023.jpg
# Working on NYC00024.jpg
# Working on NYC00025.jpg
# Working on NYC00026.jpg
# Working on NYC00027.jpg
# Working on NYC00028.jpg
# Working on NYC00029.jpg
# Working on NYC00030.jpg
# Working on NYC00031.jpg
# Working on NYC00032.jpg
# Working on NYC00033.jpg
# Working on NYC00034.jpg
# Working on NYC00035.jpg
# Working on NYC00036.jpg
# Working on NYC00037.jpg
# Working on NYC00038.jpg
# Working on NYC00039.jpg
# Working on NYC00040.jpg
# Working on NYC00041.jpg
# Working on NYC00042.jpg
# Working on NYC00043.jpg
# Working on NYC00044.jpg
# Working on NYC00045.jpg
# Working on NYC00046.jpg
# Working on NYC00047.jpg
# Working on NYC00048.jpg
# Working on NYC00049.jpg
# Working on NYC00050.jpg
# Working on NYC00051.jpg
# Working on NYC00052.jpg
# Working on NYC00053.jpg
# Working on NYC00054.jpg
# Working on NYC00055.jpg
# Working on NYC00056.jpg
# Working on NYC00057.jpg
# Working on NYC00058.jpg
# Working on NYC00059.jpg
# Working on NYC00060.jpg
# Working on NYC00061.jpg
# Working on NYC00062.jpg
# Working on NYC00063.jpg
# Working on NYC00064.jpg
# Working on NYC00065.jpg
# Working on NYC00066.jpg
# Working on NYC00067.jpg
# Working on NYC00068.jpg
# Working on NYC00069.jpg
# Working on NYC00070.jpg
# Working on NYC00071.jpg
# Working on NYC00072.jpg
# Working on NYC00073.jpg
# Working on NYC00074.jpg
# Working on NYC00075.jpg
# Working on NYC00076.jpg
# Working on NYC00077.jpg
# Working on NYC00078.jpg
# Working on NYC00079.jpg
# Working on NYC00080.jpg
# Working on NYC00081.jpg
# Working on NYC00082.jpg
# Working on NYC00083.jpg
# Working on NYC00084.jpg
# Working on NYC00085.jpg
# Working on NYC00086.jpg
# Working on NYC00087.jpg
# Working on NYC00088.jpg
# Working on NYC00089.jpg
# Working on NYC00090.jpg
# Working on NYC00091.jpg
# Working on NYC00092.jpg
# Working on NYC00093.jpg
# Working on NYC00094.jpg
# Working on NYC00095.jpg
# Working on NYC00096.jpg
# Working on NYC00097.jpg
# Working on NYC00098.jpg
# Working on NYC00099.jpg
# Working on NYC00100.jpg
# Working on NYC00101.jpg
# Working on NYC00102.jpg
# Working on NYC00103.jpg
# Working on NYC00104.jpg
# Working on NYC00105.jpg
# Working on NYC00106.jpg
# Working on NYC00107.jpg
# Working on NYC00108.jpg
# Working on NYC00109.jpg
# Working on NYC00110.jpg
# Working on NYC00111.jpg
# Working on NYC00112.jpg
# Working on NYC00113.jpg
# Working on NYC00114.jpg
# Working on NYC00115.jpg
# Working on NYC00116.jpg
# Working on NYC00117.jpg
# Working on NYC00118.jpg
# Working on NYC00119.jpg
# Working on NYC00120.jpg
# Working on NYC00121.jpg
# Working on NYC00122.jpg
# Working on NYC00123.jpg
# Working on NYC00124.jpg
# Working on NYC00125.jpg
# Working on NYC00126.jpg
# Working on NYC00127.jpg
# Working on NYC00128.jpg
# Working on NYC00129.jpg
# Working on NYC00130.jpg
# Working on NYC00131.jpg
# Working on NYC00132.jpg
# Working on NYC00133.jpg
# Working on NYC00134.jpg
# Working on NYC00135.jpg
# Working on NYC00136.jpg
# Working on NYC00137.jpg
# Working on NYC00138.jpg
# Working on NYC00139.jpg
# Working on NYC00140.jpg
# Working on NYC00141.jpg
# Working on NYC00142.jpg
# Working on NYC00143.jpg
# Working on NYC00144.jpg
# Working on NYC00145.jpg
# Working on NYC00146.jpg
# Working on NYC00147.jpg
# Working on NYC00148.jpg
# Working on NYC00149.jpg
# Working on NYC00150.jpg
# Working on NYC00151.jpg
# Working on NYC00152.jpg
# Working on NYC00153.jpg
# Working on NYC00154.jpg
# Working on NYC00155.jpg
# Working on NYC00156.jpg
# Working on NYC00157.jpg
# Working on NYC00158.jpg
# Working on NYC00159.jpg
# Working on NYC00160.jpg
# Working on NYC00161.jpg
# Working on NYC00162.jpg
# Working on NYC00163.jpg
# Working on NYC00164.jpg
# Working on NYC00165.jpg
# Working on NYC00166.jpg
# Working on NYC00167.jpg
# Working on NYC00168.jpg
# Working on NYC00169.jpg
# Working on NYC00170.jpg
# Working on NYC00171.jpg
# Working on NYC00172.jpg
# Working on NYC00173.jpg
# Working on NYC00174.jpg
# Working on NYC00175.jpg
# Working on NYC00176.jpg
# Working on NYC00177.jpg
# Working on NYC00178.jpg
# Working on NYC00179.jpg
# Working on NYC00180.jpg
# Working on NYC00181.jpg
# Working on NYC00182.jpg
# Working on NYC00183.jpg
# Working on NYC00184.jpg
# Working on NYC00185.jpg
# Working on NYC00186.jpg
# Working on NYC00187.jpg
# Working on NYC00188.jpg
# Working on NYC00189.jpg
# Working on NYC00190.jpg
# Working on NYC00191.jpg
# Working on NYC00192.jpg
# Working on NYC00193.jpg
# Working on NYC00194.jpg
# Working on NYC00195.jpg
# Working on NYC00196.jpg
# Working on NYC00197.jpg
# Working on NYC00198.jpg
# Working on NYC00199.jpg
# Working on NYC00200.jpg
# Working on NYC00201.jpg
# Working on NYC00202.jpg
# Working on NYC00203.jpg
# Working on NYC00204.jpg
# Working on NYC00205.jpg
# Working on NYC00206.jpg
# Working on NYC00207.jpg
# Working on NYC00208.jpg
# Working on NYC00209.jpg
# Working on NYC00210.jpg
# Working on NYC00211.jpg
# Working on NYC00212.jpg
# Working on NYC00213.jpg
# Working on NYC00214.jpg
# Working on NYC00215.jpg
# Working on NYC00216.jpg
# Working on NYC00217.jpg
# Working on NYC00218.jpg
# Working on NYC00219.jpg
# Working on NYC00220.jpg
# Working on NYC00221.jpg
# Working on NYC00222.jpg
# Working on NYC00223.jpg
# Working on NYC00224.jpg
# Working on NYC00225.jpg
# Working on NYC00226.jpg
# Working on NYC00227.jpg
# Working on NYC00228.jpg
# Working on NYC00229.jpg
# Working on NYC00230.jpg
# Working on NYC00231.jpg
# Working on NYC00232.jpg
# Working on NYC00233.jpg
# Working on NYC00234.jpg
# Working on NYC00235.jpg
# Working on NYC00236.jpg
# Working on NYC00237.jpg
# Working on NYC00238.jpg
# Working on NYC00239.jpg
# Working on NYC00240.jpg
# Working on NYC00241.jpg
# Working on NYC00242.jpg
# Working on NYC00243.jpg
# Working on NYC00244.jpg
# Working on NYC00245.jpg
# Working on NYC00246.jpg
# Working on NYC00247.jpg
# Working on NYC00248.jpg
# Working on NYC00249.jpg
# Working on NYC00250.jpg
# Working on NYC00251.jpg
# Working on NYC00252.jpg
# Working on NYC00253.jpg
# Working on NYC00254.jpg
# Working on NYC00255.jpg
# Working on NYC00256.jpg
# Working on NYC00257.jpg
# Working on NYC00258.jpg
# Working on NYC00259.jpg
# Working on NYC00260.jpg
# Working on NYC00261.jpg
# Working on NYC00262.jpg
# Working on NYC00263.jpg
# Working on NYC00264.jpg
# Working on NYC00265.jpg
# Working on NYC00266.jpg
# Working on NYC00267.jpg
# Working on NYC00268.jpg
# Working on NYC00269.jpg
# Working on NYC00270.jpg
# Working on NYC00271.jpg
# Working on NYC00272.jpg
# Working on NYC00273.jpg
# Working on NYC00274.jpg
# Working on NYC00275.jpg
# Working on NYC00276.jpg
# Working on NYC00277.jpg
# Working on NYC00278.jpg
# Working on NYC00279.jpg
# Working on NYC00280.jpg
# Working on NYC00281.jpg
# Working on NYC00282.jpg
# Working on NYC00283.jpg
# Working on NYC00284.jpg
# Working on NYC00285.jpg
# Working on NYC00286.jpg
# Working on NYC00287.jpg
# Working on NYC00288.jpg
# Working on NYC00289.jpg
# Working on NYC00290.jpg
# Working on NYC00291.jpg
# Working on NYC00292.jpg
# Working on NYC00293.jpg
# Working on NYC00294.jpg
# Working on NYC00295.jpg
# Working on NYC00296.jpg
# Working on NYC00297.jpg
# Working on NYC00298.jpg
# Working on NYC00299.jpg
# Working on NYC00300.jpg
# Working on NYC00301.jpg
# Working on NYC00302.jpg
# Working on NYC00303.jpg
# Working on NYC00304.jpg
# Working on NYC00305.jpg
# Working on NYC00306.jpg
# Working on NYC00307.jpg
# Working on NYC00308.jpg
# Working on NYC00309.jpg
# Working on NYC00310.jpg
# Working on NYC00311.jpg
# Working on NYC00312.jpg
# Working on NYC00313.jpg
# Working on NYC00314.jpg
# Working on NYC00315.jpg
# Working on NYC00316.jpg
# Working on NYC00317.jpg
# Working on NYC00318.jpg
# Working on NYC00319.jpg
# Working on NYC00320.jpg
# Working on NYC00321.jpg
# Working on NYC00322.jpg
# Working on NYC00323.jpg
# Working on NYC00324.jpg
# Working on NYC00325.jpg
# Working on NYC00326.jpg
# Working on NYC00327.jpg
# Working on NYC00328.jpg
# Working on NYC00329.jpg
# Working on NYC00330.jpg
# Working on NYC00331.jpg
# Working on NYC00332.jpg
# Working on NYC00333.jpg
# Working on NYC00334.jpg
# Working on NYC00335.jpg
# Working on NYC00336.jpg
# Working on NYC00337.jpg
# Working on NYC00338.jpg
# Working on NYC00339.jpg
# Working on NYC00340.jpg
# Working on NYC00341.jpg
# Working on NYC00342.jpg
# Working on NYC00343.jpg
# Working on NYC00344.jpg
# Working on NYC00345.jpg
# Working on NYC00346.jpg
# Working on NYC00347.jpg
# Working on NYC00348.jpg
# Working on NYC00349.jpg
# Working on NYC00350.jpg
# Working on NYC00351.jpg
# Working on NYC00352.jpg
# Working on NYC00353.jpg
# Working on NYC00354.jpg
# Working on NYC00355.jpg
# Working on NYC00356.jpg
# Working on NYC00357.jpg
# Working on NYC00358.jpg
# Working on NYC00359.jpg
# Working on NYC00360.jpg
# Working on NYC00361.jpg
# Working on NYC00362.jpg
# Working on NYC00363.jpg
# Working on NYC00364.jpg
# Working on NYC00365.jpg
# Working on NYC00366.jpg
# Working on NYC00367.jpg
# Working on NYC00368.jpg
# Working on NYC00369.jpg
# Working on NYC00370.jpg
# Working on NYC00371.jpg
# Working on NYC00372.jpg
# Working on NYC00373.jpg
# Working on NYC00374.jpg
# Working on NYC00375.jpg
# Working on NYC00376.jpg
# Working on NYC00377.jpg
# Working on NYC00378.jpg
# Working on NYC00379.jpg
# Working on NYC00380.jpg
# Working on NYC00381.jpg
# Working on NYC00382.jpg
# Working on NYC00383.jpg
# Working on NYC00384.jpg
# Working on NYC00385.jpg
# Working on NYC00386.jpg
# Working on NYC00387.jpg
# Working on NYC00388.jpg
# Working on NYC00389.jpg
# Working on NYC00390.jpg
# Working on NYC00391.jpg
# Working on NYC00392.jpg
# Working on NYC00393.jpg
# Working on NYC00394.jpg
# Working on NYC00395.jpg
# Working on NYC00396.jpg
# Working on NYC00397.jpg
# Working on NYC00398.jpg
# Working on NYC00399.jpg
# Working on NYC00400.jpg
# Working on NYC00401.jpg
# Working on NYC00402.jpg
# Working on NYC00403.jpg
# Working on NYC00404.jpg
# Working on NYC00405.jpg
# Working on NYC00406.jpg
# Working on NYC00407.jpg
# Working on NYC00408.jpg
# Working on NYC00409.jpg
# Working on NYC00410.jpg
# Working on NYC00411.jpg
# Working on NYC00412.jpg
# Working on NYC00413.jpg
# Working on NYC00414.jpg
# Working on NYC00415.jpg
# Working on NYC00416.jpg
# Working on NYC00417.jpg
# Working on NYC00418.jpg
# Working on NYC00419.jpg
# Working on NYC00420.jpg
# Working on NYC00421.jpg
# Working on NYC00422.jpg
# Working on NYC00423.jpg
# Working on NYC00424.jpg
# Working on NYC00425.jpg
# Working on NYC00426.jpg
# Working on NYC00427.jpg
# Working on NYC00428.jpg
# Working on NYC00429.jpg
# Working on NYC00430.jpg
# Working on NYC00431.jpg
# Working on NYC00432.jpg
# Working on NYC00433.jpg
# Working on NYC00434.jpg
# Working on NYC00435.jpg
# Working on NYC00436.jpg
# Working on NYC00437.jpg
# Working on NYC00438.jpg
# Working on NYC00439.jpg
# Working on NYC00440.jpg
# Working on NYC00441.jpg
# Working on NYC00442.jpg
# Working on NYC00443.jpg
# Working on NYC00444.jpg
# Working on NYC00445.jpg
# Working on NYC00446.jpg
# Working on NYC00447.jpg
# Working on NYC00448.jpg
# Working on NYC00449.jpg
# Working on NYC00450.jpg
# Working on NYC00451.jpg
# Working on NYC00452.jpg
# Working on NYC00453.jpg
# Working on NYC00454.jpg
# Working on NYC00455.jpg
# Working on NYC00456.jpg
# Working on NYC00457.jpg
# Working on NYC00458.jpg
# Working on NYC00459.jpg
# Working on NYC00460.jpg
# Working on NYC00461.jpg
# Working on NYC00462.jpg
# Working on NYC00463.jpg
# Working on NYC00464.jpg
# Working on NYC00465.jpg
# Working on NYC00466.jpg
# Working on NYC00467.jpg
# Working on NYC00468.jpg
# Working on NYC00469.jpg
# Working on NYC00470.jpg
# Working on NYC00471.jpg
# Working on NYC00472.jpg
# Working on NYC00473.jpg
# Working on NYC00474.jpg
# Working on NYC00475.jpg
# Working on NYC00476.jpg
# Working on NYC00477.jpg
# Working on NYC00478.jpg
# Working on NYC00479.jpg
# Working on NYC00480.jpg
# Working on NYC00481.jpg
# Working on NYC00482.jpg
# Working on NYC00483.jpg
# Working on NYC00484.jpg
# Working on NYC00485.jpg
# Working on NYC00486.jpg
# Working on NYC00487.jpg
# Working on NYC00488.jpg
# Working on NYC00489.jpg
# Working on NYC00490.jpg
# Working on NYC00491.jpg
# Working on NYC00492.jpg
# Working on NYC00493.jpg
# Working on NYC00494.jpg
# Working on NYC00495.jpg
# Working on NYC00496.jpg
# Working on NYC00497.jpg
# Working on NYC00498.jpg
# Working on NYC00499.jpg
# Working on NYC00500.jpg
# Working on NYC00501.jpg
# Working on NYC00502.jpg
# Working on NYC00503.jpg
# Working on NYC00504.jpg
# Working on NYC00505.jpg
# Working on NYC00506.jpg
# Working on NYC00507.jpg
# Working on NYC00508.jpg
# Working on NYC00509.jpg
# Working on NYC00510.jpg
# Working on NYC00511.jpg
# Working on NYC00512.jpg
# Working on NYC00513.jpg
# Working on NYC00514.jpg
# Working on NYC00515.jpg
# Working on NYC00516.jpg
# Working on NYC00517.jpg
# Working on NYC00518.jpg
# Working on NYC00519.jpg
# Working on NYC00520.jpg
# Working on NYC00521.jpg
# Working on NYC00522.jpg
# Working on NYC00523.jpg
# Working on NYC00524.jpg
# Working on NYC00525.jpg
# Working on NYC00526.jpg
# Working on NYC00527.jpg
# Working on NYC00528.jpg
# Working on NYC00529.jpg
# Working on NYC00530.jpg
# Working on NYC00531.jpg
# Working on NYC00532.jpg
# Working on NYC00533.jpg
# Working on NYC00534.jpg
# Working on NYC00535.jpg
# Working on NYC00536.jpg
# Working on NYC00537.jpg
# Working on NYC00538.jpg
# Working on NYC00539.jpg
# Working on NYC00540.jpg
# Working on NYC00541.jpg
# Working on NYC00542.jpg
# Working on NYC00543.jpg
# Working on NYC00544.jpg
# Working on NYC00545.jpg
# Working on NYC00546.jpg
# Working on NYC00547.jpg
# Working on NYC00548.jpg
# Working on NYC00549.jpg
# Working on NYC00550.jpg
# Working on NYC00551.jpg
# Working on NYC00552.jpg
# Working on NYC00553.jpg
# Working on NYC00554.jpg
# Working on NYC00555.jpg
# Working on NYC00556.jpg
# Working on NYC00557.jpg
# Working on NYC00558.jpg
# Working on NYC00559.jpg
# Working on NYC00560.jpg
# Working on NYC00561.jpg
# Working on NYC00562.jpg
# Working on NYC00563.jpg
# Working on NYC00564.jpg
# Working on NYC00565.jpg
# Working on NYC00566.jpg
# Working on NYC00567.jpg
# Working on NYC00568.jpg
# Working on NYC00569.jpg
# Working on NYC00570.jpg
# Working on NYC00571.jpg
# Working on NYC00572.jpg
# Working on NYC00573.jpg
# Working on NYC00574.jpg
# Working on NYC00575.jpg
# Working on NYC00576.jpg
# Working on NYC00577.jpg
# Working on NYC00578.jpg
# Working on NYC00579.jpg
# Working on NYC00580.jpg
# Working on NYC00581.jpg
# Working on NYC00582.jpg
# Working on NYC00583.jpg
# Working on NYC00584.jpg
# Working on NYC00585.jpg
# Working on NYC00586.jpg
# Working on NYC00587.jpg
# Working on NYC00588.jpg
# Working on NYC00589.jpg
# Working on NYC00590.jpg
# Working on NYC00591.jpg
# Working on NYC00592.jpg
# Working on NYC00593.jpg
# Working on NYC00594.jpg
# Working on NYC00595.jpg
# Working on NYC00596.jpg
# Working on NYC00597.jpg
# Working on NYC00598.jpg
# Working on NYC00599.jpg
# Working on NYC00600.jpg
# Working on NYC00601.jpg
# Working on NYC00602.jpg
# Working on NYC00603.jpg
# Working on NYC00604.jpg
# Working on NYC00605.jpg
# Working on NYC00606.jpg
# Working on NYC00607.jpg
# Working on NYC00608.jpg
# Working on NYC00609.jpg
# Working on NYC00610.jpg
# Working on NYC00611.jpg
# Working on NYC00612.jpg
# Working on NYC00613.jpg
# Working on NYC00614.jpg
# Working on NYC00615.jpg
# Working on NYC00616.jpg
# Working on NYC00617.jpg
# Working on NYC00618.jpg
# Working on NYC00619.jpg
# Working on NYC00620.jpg
# Working on NYC00621.jpg
